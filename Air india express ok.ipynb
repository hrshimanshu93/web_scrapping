# %%
import openpyxl
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd
import numpy as np
import re

# Load selenium path 
service = Service(executable_path=r'C:\work\selenium\chromedriver.exe')
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

# Load the input Excel file
input_file_path = r'C:\Users\Himanshu\Downloads\Air India express.xlsx'
workbook = openpyxl.load_workbook(input_file_path)
sheet = workbook.active

# Iterate through the rows in the Excel file
for row in sheet.iter_rows(min_row=2, min_col=1, max_col=3, values_only=True):
    airline_pnr, pax_first_name, pax_last_name = row

    # Construct the URL with the last name and PNR
    url = f'https://www.airindiaexpress.in/manage?&recordLocator={pnr}&addtnlDetail={lastName}'

    # Make a GET request to the URL
    driver.get(url)
    driver.maximize_window()
    sleep(1)

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'lxml')

    # Extract booking status
    if booking_status is None:
        booking_status = soup.find('strong').text
        # Code to execute if booking_status is None
    else if:
        # Code to execute if booking_status is not None
        booking_status = soup.find('div', class_='cancel-refund-title').text
        # Extract payment status
        refund_amount = soup.find('span', class_='item-value').text

        # Extract payment details
        airfare_cost = soup.find('span', class_='heading-component-amount').text
        other_fees_taxes = [item.text for item in soup.find_all('span', class_='heading-component-amount')]
    else:
        refund_amount = soup.find('span', class_='item-value').text

    # Write the extracted data back to the Excel file
    sheet.cell(row=sheet.max_row + 1, column=4, value=booking_status)
    sheet.cell(row=sheet.max_row, column=5, value=refund_amount)
    sheet.cell(row=sheet.max_row, column=6, value=airfare_cost)
    sheet.cell(row=sheet.max_row, column=7, value=', '.join(other_fees_taxes))

# Save the updated Excel file
output_file_path = 'output.xlsx'
workbook.save(output_file_path)
# Out:
#   Cell In[1], line 41
#     else if:
#          ^
# SyntaxError: expected ':'

# %%
import openpyxl
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep

# Load the input Excel file
input_file_path = r'C:\Users\Himanshu\Downloads\IX_DATA06JUN.xlsx'
workbook = openpyxl.load_workbook(input_file_path)
sheet = workbook.active

# Initialize the Chrome WebDriver
driver = webdriver.Chrome()

# Iterate through the rows in the Excel file
for row in sheet.iter_rows(min_row=2, min_col=1, max_col=3, values_only=True):
    airline_pnr, pax_first_name, pax_last_name = row

    # Construct the URL with the last name and PNR
    url = f'https://www.airindiaexpress.in/manage?&recordLocator={airline_pnr}&addtnlDetail={pax_last_name}'

    # Make a GET request to the URL
    driver.get(url)
    sleep(2)  # Add a delay to allow the page to load

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Extract booking status
    booking_status = soup.find('div', class_='cancel-refund-title')
    if booking_status is None:
        booking_status = soup.find('strong').text
    else:
        booking_status = booking_status.text

    if booking_status != "Booking Cancelled":
        # Extract payment status
        refund_amount = soup.find('span', class_='item-value').text

        # Extract payment details
        airfare_cost = soup.find('span', class_='heading-component-amount').text
        other_fees_taxes = [item.text for item in soup.find_all('span', class_='heading-component-amount')]
    else:
        refund_amount = soup.find('span', class_='item-value').text

    # Write the extracted data back to the Excel file
    sheet.append([booking_status, refund_amount, airfare_cost, ', '.join(other_fees_taxes)])

# Save the updated Excel file
output_file_path = 'output_06JUN.xlsx'
workbook.save(output_file_path)

# Quit the WebDriver
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 37
#      33     booking_status = booking_status.text
#      35 if booking_status != "Booking Cancelled":
#      36     # Extract payment status
# ---> 37     refund_amount = soup.find('span', class_='item-value').text
#      39     # Extract payment details
#      40     airfare_cost = soup.find('span', class_='heading-component-amount').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import openpyxl
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep

# Load the input Excel file
input_file_path = r'C:\Users\Himanshu\Downloads\IX_DATA1.xlsx'
workbook = openpyxl.load_workbook(input_file_path)
sheet = workbook.active

# Initialize the Chrome WebDriver
driver = webdriver.Chrome()

# Iterate through the rows in the Excel file
for row in sheet.iter_rows(min_row=2, min_col=1, max_col=3, values_only=True):
    airline_pnr, pax_first_name, pax_last_name = row

    # Construct the URL with the last name and PNR
    url = f'https://www.airindiaexpress.in/manage?&recordLocator={airline_pnr}&addtnlDetail={pax_last_name}'

    # Make a GET request to the URL
    driver.get(url)
    sleep(2)  # Add a delay to allow the page to load

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Extract booking status
    booking_status = soup.find('div', class_='cancel-refund-title')
    if booking_status is None:
        booking_status = soup.find('strong').text
    else:
        booking_status = booking_status.text

    if booking_status != "Booking Cancelled":
        # Extract payment status
        refund_amount = soup.find('span', class_='item-value').text

        # Extract payment details
        airfare_cost = soup.find('span', class_='heading-component-amount').text
        other_fees_taxes = [item.text for item in soup.find_all('span', class_='heading-component-amount')]
    else:
        refund_amount = soup.find('span', class_='item-value').text

   # Write the extracted data back to the Excel file
    sheet.cell(row=sheet.max_row + 1, column=4, value=booking_status)
    sheet.cell(row=sheet.max_row, column=5, value=refund_amount)
    sheet.cell(row=sheet.max_row, column=6, value=airfare_cost)
    sheet.cell(row=sheet.max_row, column=7, value=', '.join(other_fees_taxes))

# Save the updated Excel file
output_file_path = 'output.xlsx'
workbook.save(output_file_path)

# Quit the WebDriver
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 37
#      33     booking_status = booking_status.text
#      35 if booking_status != "Booking Cancelled":
#      36     # Extract payment status
# ---> 37     refund_amount = soup.find('span', class_='item-value').text
#      39     # Extract payment details
#      40     airfare_cost = soup.find('span', class_='heading-component-amount').text
#
# AttributeError: 'NoneType' object has no attribute 'text'
